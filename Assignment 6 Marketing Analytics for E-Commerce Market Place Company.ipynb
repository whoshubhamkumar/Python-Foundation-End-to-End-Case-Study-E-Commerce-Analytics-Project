# %% [markdown]
# ## Marketing Analytics for E-Commerce Market Place Company

# %%
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
Customers=pd.read_csv(r'CUSTOMERS.csv').convert_dtypes()
Customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh

# %%
Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  string
#  1   customer_unique_id        99441 non-null  string
#  2   customer_zip_code_prefix  99441 non-null  Int64
#  3   customer_city             99441 non-null  string
#  4   customer_state            99441 non-null  string
# dtypes: Int64(1), string(4)
# memory usage: 3.9 MB

# %%
Orders=pd.read_csv(r'ORDERS.csv').convert_dtypes()
Orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp order_approved_at  \
# 0    delivered          10/2/2017 10:56   10/2/2017 11:07
# 1    delivered          7/24/2018 20:41    7/26/2018 3:24
# 2    delivered            8/8/2018 8:38     8/8/2018 8:55
# 3    delivered         11/18/2017 19:28  11/18/2017 19:45
# 4    delivered          2/13/2018 21:18   2/13/2018 22:20
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0              10/4/2017 19:55              10/10/2017 21:25
# 1              7/26/2018 14:31                8/7/2018 15:27
# 2               8/8/2018 13:50               8/17/2018 18:06
# 3             11/22/2017 13:39                12/2/2017 0:28
# 4              2/14/2018 19:46               2/16/2018 18:17
#
#   order_estimated_delivery_date
# 0               10/18/2017 0:00
# 1                8/13/2018 0:00
# 2                 9/4/2018 0:00
# 3               12/15/2017 0:00
# 4                2/26/2018 0:00

# %%
Orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  string
#  1   customer_id                    99441 non-null  string
#  2   order_status                   99441 non-null  string
#  3   order_purchase_timestamp       99441 non-null  string
#  4   order_approved_at              99281 non-null  string
#  5   order_delivered_carrier_date   97658 non-null  string
#  6   order_delivered_customer_date  96476 non-null  string
#  7   order_estimated_delivery_date  99441 non-null  string
# dtypes: string(8)
# memory usage: 6.1 MB

# %%
Products=pd.read_csv(r'PRODUCTS.csv').convert_dtypes()
Products.tail()
# Out:
#                              product_id      product_category_name  \
# 32946  a0b7d5a992ccda646f2d34e418fff5a0            Furniture_Decor
# 32947  bf4538d88321d0fd4412a93c974510e6  Construction_Tools_Lights
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c             Bed_Bath_Table
# 32949  83808703fc0706a22e264b9d75f04a2e      Computers_Accessories
# 32950  106392145fca363410d287a815be6de4             Bed_Bath_Table
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 32946                   45                          67                   2
# 32947                   41                         971                   1
# 32948                   50                         799                   1
# 32949                   60                         156                   2
# 32950                   58                         309                   1
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 32946             12300                 40                 40
# 32947              1700                 16                 19
# 32948              1400                 27                  7
# 32949               700                 31                 13
# 32950              2083                 12                  2
#
#        product_width_cm
# 32946                40
# 32947                16
# 32948                27
# 32949                20
# 32950                 7

# %%
Sellers=pd.read_csv(r'SELLERS.csv').convert_dtypes()
Sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix   seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023         Alwal
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13023         Alwal
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031     Badepalle
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195  Akkarampalle
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914       Koratla
#
#      seller_state
# 0  Andhra Pradesh
# 1  Andhra Pradesh
# 2  Andhra Pradesh
# 3  Andhra Pradesh
# 4  Andhra Pradesh

# %%
Geo_Location=pd.read_csv(r'GEO_LOCATION.csv').convert_dtypes()
Geo_Location.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081        -46.64482
# 2                         1041       -23.544392       -46.639499
# 3                         1035       -23.541578       -46.641607
# 4                         1012       -23.547762       -46.635361
#
#   geolocation_city geolocation_state
# 0     Akkarampalle    Andhra Pradesh
# 1     Akkarampalle    Andhra Pradesh
# 2     Akkarampalle    Andhra Pradesh
# 3     Akkarampalle    Andhra Pradesh
# 4     Akkarampalle    Andhra Pradesh

# %%
Order_Items=pd.read_csv(r'ORDER_ITEMS.csv').convert_dtypes()
Order_Items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date  price  freight_value
# 0      9/19/2017 9:45   58.9          13.29
# 1      5/3/2017 11:05  239.9          19.93
# 2     1/18/2018 14:48  199.0          17.87
# 3     8/15/2018 10:10  12.99          12.79
# 4     2/13/2017 13:57  199.9          18.14

# %%
Order_Payments=pd.read_csv(r'ORDER_PAYMENTS.csv').convert_dtypes()
Order_Payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
Order_Review_Ratings=pd.read_csv(r'ORDER_REVIEW_RATINGS.csv').convert_dtypes()
Order_Review_Ratings.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_creation_date review_answer_timestamp
# 0             4       1/18/2018 0:00         1/18/2018 21:46
# 1             5       3/10/2018 0:00          3/11/2018 3:05
# 2             5       2/17/2018 0:00         2/18/2018 14:36
# 3             5       4/21/2017 0:00         4/21/2017 22:02
# 4             5        3/1/2018 0:00          3/2/2018 10:26

# %% [markdown]
# ## 1. Perform Detailed exploratory analysis
# ### a. Define & calculate high level metrics like (Total Revenue, Total quantity, Total products,Total categories, Total sellers, Total locations, Total channels, Total payment methods etc…)

# %%
Order_Payments['Total_Payment']=Order_Payments.payment_value * Order_Payments.payment_installments
print("Total Revenue :",Order_Payments.Total_Payment.sum())
# Out:
# Total Revenue : 65763157.62

# %%
print('Total Quantity =',Order_Items.shape[0])
# Out:
# Total Quantity = 112650

# %%
print("Total Products :",Products.product_id.nunique())
# Out:
# Total Products : 32951

# %%
print("Total categories :",Products.product_category_name.nunique())
# Out:
# Total categories : 71

# %%
print("Total Sellers :",Sellers.seller_id.count())
# Out:
# Total Sellers : 3095

# %%
print("Total Locations :",Geo_Location.geolocation_zip_code_prefix.nunique())
# Out:
# Total Locations : 19015

# %%
print("Total Payment Methods :",Order_Payments.payment_type.nunique())
# Out:
# Total Payment Methods : 5

# %% [markdown]
# ### b. Understanding how many new customers acquired every month

# %%
Customers_Orders=pd.merge(left=Customers,right=Orders,on="customer_id")
Customers_Orders.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered          5/16/2017 15:05
# 1  29150127e6685892b6eab3eec79f59c7    delivered          1/12/2018 20:48
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered          5/19/2018 16:07
# 3  951670f92359f4fe4a63112aa7306eba    delivered          3/13/2018 16:06
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered           7/29/2018 9:51
#
#   order_approved_at order_delivered_carrier_date  \
# 0   5/16/2017 15:22              5/23/2017 10:47
# 1   1/12/2018 20:58              1/15/2018 17:14
# 2   5/20/2018 16:19              6/11/2018 14:31
# 3   3/13/2018 17:29              3/27/2018 23:22
# 4   7/29/2018 10:10              7/30/2018 15:16
#
#   order_delivered_customer_date order_estimated_delivery_date
# 0               5/25/2017 10:35                 6/5/2017 0:00
# 1               1/29/2018 12:41                 2/6/2018 0:00
# 2               6/14/2018 17:58                6/13/2018 0:00
# 3               3/28/2018 16:04                4/10/2018 0:00
# 4                8/9/2018 20:55                8/15/2018 0:00

# %%
Customers_Orders.order_purchase_timestamp=pd.to_datetime(Customers_Orders.order_purchase_timestamp,format='%m/%d/%Y %H:%M')

# %%
Customers_Orders['Year_Month']=Customers_Orders.order_purchase_timestamp.apply(lambda x:pd.Timestamp.strftime(x,format="%Y-%m"))
Customers_Orders.head(3)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:00
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:00
#
#   order_approved_at order_delivered_carrier_date  \
# 0   5/16/2017 15:22              5/23/2017 10:47
# 1   1/12/2018 20:58              1/15/2018 17:14
# 2   5/20/2018 16:19              6/11/2018 14:31
#
#   order_delivered_customer_date order_estimated_delivery_date Year_Month
# 0               5/25/2017 10:35                 6/5/2017 0:00    2017-05
# 1               1/29/2018 12:41                 2/6/2018 0:00    2018-01
# 2               6/14/2018 17:58                6/13/2018 0:00    2018-05

# %%
Customers_YearMonth=Customers_Orders.loc[:,['customer_unique_id','Year_Month']]

# %%
Customers_YearMonth.drop_duplicates(subset=['customer_unique_id'],keep='first',inplace=True)

# %%
New_Customers_Acquired=Customers_YearMonth.groupby('Year_Month')['customer_unique_id'].count()
New_Customers_Acquired
# Out:
# Year_Month
# 2016-09       4
# 2016-10     315
# 2017-01     749
# 2017-02    1727
# 2017-03    2595
# 2017-04    2318
# 2017-05    3533
# 2017-06    3103
# 2017-07    3864
# 2017-08    4144
# 2017-09    4089
# 2017-10    4449
# 2017-11    7305
# 2017-12    5491
# 2018-01    7029
# 2018-02    6464
# 2018-03    7001
# 2018-04    6751
# 2018-05    6678
# 2018-06    6013
# 2018-07    6117
# 2018-08    6348
# 2018-09       8
# 2018-10       1
# Name: customer_unique_id, dtype: int64

# %%
New_Customers_Acquired.plot(kind='bar',figsize=(18,7), grid = True)
plt.title("New Customer Acquired Monthly")
plt.ylabel("Customer Count")
plt.show()

# %% [markdown]
# ### c. Understand the retention of customers on month on month basis

# %%
Cust_Monthly_Count=Customers_Orders.groupby('Year_Month')[['customer_unique_id']].count().reset_index()
Cust_Monthly_Count
# Out:
#    Year_Month  customer_unique_id
# 0     2016-09                   4
# 1     2016-10                 324
# 2     2016-12                   1
# 3     2017-01                 800
# 4     2017-02                1780
# 5     2017-03                2682
# 6     2017-04                2404
# 7     2017-05                3700
# 8     2017-06                3245
# 9     2017-07                4026
# 10    2017-08                4331
# 11    2017-09                4285
# 12    2017-10                4631
# 13    2017-11                7544
# 14    2017-12                5673
# 15    2018-01                7269
# 16    2018-02                6728
# 17    2018-03                7211
# 18    2018-04                6939
# 19    2018-05                6873
# 20    2018-06                6167
# 21    2018-07                6292
# 22    2018-08                6512
# 23    2018-09                  16
# 24    2018-10                   4

# %%
Cust_Monthly_Count.customer_unique_id.sum()
# Out:
# 99441

# %%
Customers_Retention=pd.merge(left=Cust_Monthly_Count,right=New_Customers_Acquired,on='Year_Month')
Customers_Retention.head()
# Out:
#   Year_Month  customer_unique_id_x  customer_unique_id_y
# 0    2016-09                     4                     4
# 1    2016-10                   324                   315
# 2    2017-01                   800                   749
# 3    2017-02                  1780                  1727
# 4    2017-03                  2682                  2595

# %%
Customers_Retention['Customers_Retained']=Customers_Retention.customer_unique_id_x - Customers_Retention.customer_unique_id_y
Customers_Retention
# Out:
#    Year_Month  customer_unique_id_x  customer_unique_id_y  Customers_Retained
# 0     2016-09                     4                     4                   0
# 1     2016-10                   324                   315                   9
# 2     2017-01                   800                   749                  51
# 3     2017-02                  1780                  1727                  53
# 4     2017-03                  2682                  2595                  87
# 5     2017-04                  2404                  2318                  86
# 6     2017-05                  3700                  3533                 167
# 7     2017-06                  3245                  3103                 142
# 8     2017-07                  4026                  3864                 162
# 9     2017-08                  4331                  4144                 187
# 10    2017-09                  4285                  4089                 196
# 11    2017-10                  4631                  4449                 182
# 12    2017-11                  7544                  7305                 239
# 13    2017-12                  5673                  5491                 182
# 14    2018-01                  7269                  7029                 240
# 15    2018-02                  6728                  6464                 264
# 16    2018-03                  7211                  7001                 210
# 17    2018-04                  6939                  6751                 188
# 18    2018-05                  6873                  6678                 195
# 19    2018-06                  6167                  6013                 154
# 20    2018-07                  6292                  6117                 175
# 21    2018-08                  6512                  6348                 164
# 22    2018-09                    16                     8                   8
# 23    2018-10                     4                     1                   3

# %% [markdown]
# ### d. How the revenues from existing/new customers on month on month basis

# %%
Customers_Orders_Payments=pd.merge(left=Customers_Orders,right=Order_Payments,on='order_id')
Customers_Orders_Payments.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status order_purchase_timestamp  \
# 0  00e7ee1b050b8499577073aeb2a297a1    delivered      2017-05-16 15:05:00
# 1  29150127e6685892b6eab3eec79f59c7    delivered      2018-01-12 20:48:00
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2    delivered      2018-05-19 16:07:00
# 3  951670f92359f4fe4a63112aa7306eba    delivered      2018-03-13 16:06:00
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f    delivered      2018-07-29 09:51:00
#
#   order_approved_at order_delivered_carrier_date  \
# 0   5/16/2017 15:22              5/23/2017 10:47
# 1   1/12/2018 20:58              1/15/2018 17:14
# 2   5/20/2018 16:19              6/11/2018 14:31
# 3   3/13/2018 17:29              3/27/2018 23:22
# 4   7/29/2018 10:10              7/30/2018 15:16
#
#   order_delivered_customer_date order_estimated_delivery_date Year_Month  \
# 0               5/25/2017 10:35                 6/5/2017 0:00    2017-05
# 1               1/29/2018 12:41                 2/6/2018 0:00    2018-01
# 2               6/14/2018 17:58                6/13/2018 0:00    2018-05
# 3               3/28/2018 16:04                4/10/2018 0:00    2018-03
# 4                8/9/2018 20:55                8/15/2018 0:00    2018-07
#
#    payment_sequential payment_type  payment_installments  payment_value  \
# 0                   1  credit_card                     2         146.87
# 1                   1  credit_card                     8         335.48
# 2                   1  credit_card                     7         157.73
# 3                   1  credit_card                     1          173.3
# 4                   1  credit_card                     8         252.25
#
#    Total_Payment
# 0         293.74
# 1        2683.84
# 2        1104.11
# 3          173.3
# 4         2018.0

# %%
Total_Revenue=Customers_Orders_Payments.groupby('Year_Month')[['Total_Payment']].sum()
Total_Revenue
# Out:
#             Total_Payment
# Year_Month
# 2016-09            443.31
# 2016-10         311087.22
# 2016-12             19.62
# 2017-01         617745.71
# 2017-02        1195483.77
# 2017-03         2023623.1
# 2017-04        1897830.07
# 2017-05        2644531.62
# 2017-06        2328722.47
# 2017-07        2507170.36
# 2017-08        2911883.38
# 2017-09        3086009.32
# 2017-10        3313744.47
# 2017-11        5080098.45
# 2017-12        3550193.28
# 2018-01        4141702.73
# 2018-02        3603869.17
# 2018-03        4772613.39
# 2018-04        4627083.04
# 2018-05        4771945.72
# 2018-06        4195026.67
# 2018-07        4107479.31
# 2018-08        4069822.23
# 2018-09           4439.54
# 2018-10            589.67

# %%
Total_Revenue.plot(kind='line',figsize=(18,7))
# Out:
# <AxesSubplot:xlabel='Year_Month'>

# %% [markdown]
# ### e. Understand the trends/seasonality of sales, quantity by category, location, month, week, day, time, channel, payment method etc…

# %%
Orders_OI=pd.merge(left=Orders,right=Order_Items,on='order_id')
Orders_OI_Products=pd.merge(left=Orders_OI,right=Products,on='product_id')
Orders_OI_Products
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       128e10d95713541c87cd1a2e48201934  a20e8105f23924cd00833fd87daa0831
# 2       0e7e841ddf8f8f2de2bad69267ecfbcf  26c7ac168e1433912a51b924fbd34d34
# 3       bfc39df4f36c3693ff3b63fcbea9e90a  53904ddbea91e1e92b2b3f1d09a7af86
# 4       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# ...                                  ...                               ...
# 112645  e8fd20068b9f7e6ec07068bb7537f781  609b9fb8cad4fe0c7b376f77c8ab76ad
# 112646  e8fd20068b9f7e6ec07068bb7537f781  609b9fb8cad4fe0c7b376f77c8ab76ad
# 112647  cfa78b997e329a5295b4ee6972c02979  a2f7428f0cafbc8e59f20e1444b67315
# 112648  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 112649  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp order_approved_at  \
# 0         delivered          10/2/2017 10:56   10/2/2017 11:07
# 1         delivered          8/15/2017 18:29   8/15/2017 20:05
# 2         delivered           8/2/2017 18:24    8/2/2017 18:43
# 3         delivered         10/23/2017 23:26   10/25/2017 2:14
# 4         delivered          7/24/2018 20:41    7/26/2018 3:24
# ...             ...                      ...               ...
# 112645    delivered          8/10/2017 21:21   8/10/2017 21:35
# 112646    delivered          8/10/2017 21:21   8/10/2017 21:35
# 112647    delivered          12/20/2017 9:52  12/20/2017 10:09
# 112648    delivered            3/9/2017 9:54     3/9/2017 9:54
# 112649    delivered           3/8/2018 20:57    3/9/2018 11:20
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# 0                   10/4/2017 19:55              10/10/2017 21:25
# 1                   8/17/2017 15:28               8/18/2017 14:44
# 2                    8/4/2017 17:35                8/7/2017 18:30
# 3                  10/27/2017 16:48               11/7/2017 18:04
# 4                   7/26/2018 14:31                8/7/2018 15:27
# ...                             ...                           ...
# 112645              8/18/2017 16:42               8/23/2017 15:36
# 112646              8/18/2017 16:42               8/23/2017 15:36
# 112647             12/20/2017 20:25               1/26/2018 15:45
# 112648              3/10/2017 11:18               3/17/2017 15:08
# 112649               3/9/2018 22:11               3/16/2018 13:08
#
#        order_estimated_delivery_date  order_item_id  \
# 0                    10/18/2017 0:00              1
# 1                     8/28/2017 0:00              1
# 2                     8/15/2017 0:00              1
# 3                    11/13/2017 0:00              1
# 4                     8/13/2018 0:00              1
# ...                              ...            ...
# 112645                8/31/2017 0:00              1
# 112646                8/31/2017 0:00              2
# 112647                1/18/2018 0:00              1
# 112648                3/28/2017 0:00              1
# 112649                 4/3/2018 0:00              1
#
#                               product_id  ...  price freight_value  \
# 0       87285b34884572647811a353c7ac498a  ...  29.99          8.72
# 1       87285b34884572647811a353c7ac498a  ...  29.99          7.78
# 2       87285b34884572647811a353c7ac498a  ...  29.99          7.78
# 3       87285b34884572647811a353c7ac498a  ...  29.99          14.1
# 4       595fac2a385ac33a80bd5114aec74eb8  ...  118.7         22.76
# ...                                  ...  ...    ...           ...
# 112645  0df37da38a30a713453b03053d60d3f7  ...  356.0         18.12
# 112646  0df37da38a30a713453b03053d60d3f7  ...  356.0         18.12
# 112647  3d2c44374ee42b3003a470f3e937a2ea  ...   55.9         15.14
# 112648  ac35486adb7b02598c182c2ff2e05254  ...   72.0         13.08
# 112649  006619bbed68b000c8ba3f8725d5409e  ...   68.5         18.36
#
#         product_category_name  product_name_lenght product_description_lenght  \
# 0                  Housewares                   40                        268
# 1                  Housewares                   40                        268
# 2                  Housewares                   40                        268
# 3                  Housewares                   40                        268
# 4                   Perfumery                   29                        178
# ...                       ...                  ...                        ...
# 112645         Sports_Leisure                   53                       1105
# 112646         Sports_Leisure                   53                       1105
# 112647    Musical_Instruments                   34                        372
# 112648          Health_Beauty                   50                       1517
# 112649          Health_Beauty                   45                        569
#
#         product_photos_qty  product_weight_g  product_length_cm  \
# 0                        4               500                 19
# 1                        4               500                 19
# 2                        4               500                 19
# 3                        4               500                 19
# 4                        1               400                 19
# ...                    ...               ...                ...
# 112645                   1              2800                 28
# 112646                   1              2800                 28
# 112647                   2               300                 16
# 112648                   1              1175                 22
# 112649                   1               150                 16
#
#         product_height_cm  product_width_cm
# 0                       8                13
# 1                       8                13
# 2                       8                13
# 3                       8                13
# 4                      13                19
# ...                   ...               ...
# 112645                 23                23
# 112646                 23                23
# 112647                  6                12
# 112648                 13                18
# 112649                  7                15
#
# [112650 rows x 22 columns]

# %%
Orders_OI_Products.order_purchase_timestamp=pd.to_datetime(Orders_OI_Products.order_purchase_timestamp,format='%m/%d/%Y %H:%M')

# %%
Orders_OI_Products['Month']=Orders_OI_Products.order_purchase_timestamp.apply(lambda x:pd.Timestamp.strftime(x,format="%b"))

# %%
# Trend of sales and quantity by category

Orders_OI_Products.groupby('product_category_name').agg({'product_id':'count','price':'sum'}).rename(columns={'product_id':'Quantity','price':'Sales'})
# Out:
#                             Quantity       Sales
# product_category_name
# Agro_Industry_And_Commerce       212    72530.47
# Air_Conditioning                 297    55024.96
# Art                              209    24202.64
# Arts_And_Craftmanship             24     1814.01
# Audio                            364     50688.5
# ...                              ...         ...
# Stationery                      2517   230943.23
# Tablets_Printing_Image            83     7528.41
# Telephony                       4545   323667.53
# Toys                            4117    483946.6
# Watches_Gifts                   5991  1205005.68
#
# [71 rows x 2 columns]

# %%
# Seasonality of sales and quantity by Month

Orders_OI_Products.groupby('Month').agg({'product_id':'count','price':'sum'}).rename(columns={'product_id':'Quantity','price':'Sales'})
# Out:
#        Quantity       Sales
# Month
# Apr       10659  1356574.98
# Aug       12158  1428658.01
# Dec        6309   743925.07
# Feb        9623  1091481.73
# Jan        9163  1070343.23
# Jul       11611   1393538.7
# Jun       10661  1298162.91
# Mar       11217  1357557.74
# May       12061  1502588.82
# Nov        8665  1010271.37
# Oct        5685   713727.09
# Sep        4838   624814.05

# %%
# Trend of sales & quantity  by Payment Type

Customers_Orders_Payments.groupby('payment_type').agg({'order_id':'count','payment_value':'sum'}).rename(columns={'order_id':'Quantity','payment_value':'Sales'})
# Out:
#               Quantity        Sales
# payment_type
# UPI              19784   2869361.27
# credit_card      76795  12542084.19
# debit_card        1529    217989.79
# not_defined          3          0.0
# voucher           5775    379436.87

# %%
# Trend of sales & quantity by location

Customers_Orders_Payments.groupby('customer_state').agg({'order_id':'count','Total_Payment':'sum'}).rename(columns={'order_id':'Quantity','Total_Payment':'Sales'})
# Out:
#                    Quantity       Sales
# customer_state
# Andhra Pradesh        63563  37313149.3
# Arunachal Pradesh      1157   812340.62
# Chhattisgarh           6622  4687424.95
# Delhi                  3485   2469990.1
# Goa                      10     2825.88
# Gujarat                7782  5418861.02
# Haryana                2320  1517763.67
# Himachal Pradesh        762   542289.78
# Jammu & Kashmir        1587  1126724.21
# Karnataka              4035  2697659.52
# Kerala                 1589  1034505.75
# Madhya Pradesh         2970  2166778.12
# Maharashtra            2076  1476700.73
# Orissa                  644   516093.18
# Punjab                  700   471026.24
# Rajasthan               833    682085.6
# Tamil Nadu             2204  1614426.72
# Uttar Pradesh          1069   824638.92
# Uttaranchal             101    69415.49
# West Bengal             377   318457.82

# %% [markdown]
# ### f. Popular Products by month, seller, state, category.

# %%
# Popular Products by Category

Popular_bycategory=Orders_OI_Products.groupby('product_category_name').agg({'product_id':'count'}).rename(columns={'product_id':'Quantity'}).sort_values(by='Quantity',ascending=False)
Popular_bycategory
# Out:
#                            Quantity
# product_category_name
# Bed_Bath_Table                11115
# Health_Beauty                  9670
# Sports_Leisure                 8641
# Furniture_Decor                8334
# Computers_Accessories          7827
# ...                             ...
# Arts_And_Craftmanship            24
# La_Cuisine                       14
# Cds_Dvds_Musicals                14
# Fashion_Childrens_Clothes         8
# Security_And_Services             2
#
# [71 rows x 1 columns]

# %%
# Popular Products by Month

Popular_bymonth=Orders_OI_Products.groupby(['Month','product_category_name']).agg({'product_id':'count'}).rename(columns={'product_id':'Quantity'})
Popular_bymonth=Popular_bymonth.sort_values(by=['Quantity'],ascending=False)
Popular_bymonth.head(15)
# Out:
#                              Quantity
# Month product_category_name
# Aug   Health_Beauty              1209
# Jul   Bed_Bath_Table             1203
# Aug   Bed_Bath_Table             1170
# Jun   Bed_Bath_Table             1155
#       Health_Beauty              1145
# May   Bed_Bath_Table             1116
# Jul   Health_Beauty              1100
# Mar   Bed_Bath_Table             1087
# Feb   Computers_Accessories      1087
# May   Health_Beauty              1060
# Apr   Bed_Bath_Table             1020
# Nov   Bed_Bath_Table              975
# Mar   Sports_Leisure              960
#       Computers_Accessories       932
# May   Housewares                  926

# %%
# Popular Products by State

Customers_Orders_Payments_OI_Products=pd.merge(left=Customers_Orders_Payments,right=Orders_OI_Products,on='order_id')
Customers_Orders_Payments_OI_Products.head()
# Out:
#                       customer_id_x                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix customer_city  customer_state  \
# 0                     14409      Adilabad  Andhra Pradesh
# 1                      9790         Adoni  Andhra Pradesh
# 2                      1151  Akkarampalle  Andhra Pradesh
# 3                      8775   Akkayapalle  Andhra Pradesh
# 4                     13056         Alwal  Andhra Pradesh
#
#                            order_id order_status_x order_purchase_timestamp_x  \
# 0  00e7ee1b050b8499577073aeb2a297a1      delivered        2017-05-16 15:05:00
# 1  29150127e6685892b6eab3eec79f59c7      delivered        2018-01-12 20:48:00
# 2  b2059ed67ce144a36e2aa97d2c9e9ad2      delivered        2018-05-19 16:07:00
# 3  951670f92359f4fe4a63112aa7306eba      delivered        2018-03-13 16:06:00
# 4  6b7d50bd145f6fc7f33cebabd7e49d0f      delivered        2018-07-29 09:51:00
#
#   order_approved_at_x order_delivered_carrier_date_x  ... freight_value  \
# 0     5/16/2017 15:22                5/23/2017 10:47  ...         21.88
# 1     1/12/2018 20:58                1/15/2018 17:14  ...         46.48
# 2     5/20/2018 16:19                6/11/2018 14:31  ...         17.79
# 3     3/13/2018 17:29                3/27/2018 23:22  ...         23.36
# 4     7/29/2018 10:10                7/30/2018 15:16  ...         22.25
#
#   product_category_name product_name_lenght  product_description_lenght  \
# 0      Office_Furniture                  41                        1141
# 1            Housewares                  43                        1002
# 2      Office_Furniture                  55                         955
# 3      Office_Furniture                  48                        1066
# 4          Home_Confort                  61                         407
#
#   product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                  1              8683                 54                 64
# 1                  3             10150                 89                 15
# 2                  1              8267                 52                 52
# 3                  1             12160                 56                 51
# 4                  1              5200                 45                 15
#
#   product_width_cm Month
# 0               31   May
# 1               40   Jan
# 2               17   May
# 3               28   Mar
# 4               35   Jul
#
# [5 rows x 40 columns]

# %%
Popular_bystate=Customers_Orders_Payments_OI_Products.groupby(['customer_state','product_category_name']).agg({'order_id':'count'}).rename(columns={'order_id':'Quantity'})
Popular_bystate=Popular_bystate.sort_values(by=['Quantity'],ascending=False)
Popular_bystate
# Out:
#                                              Quantity
# customer_state    product_category_name
# Andhra Pradesh    Bed_Bath_Table                 7629
#                   Health_Beauty                  6202
#                   Sports_Leisure                 5525
#                   Furniture_Decor                5517
#                   Computers_Accessories          5020
# ...                                               ...
# Haryana           Furniture_Bedroom                 1
# Arunachal Pradesh Costruction_Tools_Tools           1
# Uttar Pradesh     Construction_Tools_Safety         1
# Delhi             Books_Imported                    1
# Uttar Pradesh     Fashion_Underwear_Beach           1
#
# [1076 rows x 1 columns]

# %%
# Popular Products by Seller

COOIPPS=pd.merge(left=Customers_Orders_Payments_OI_Products,right=Sellers,on='seller_id')
COOIPPS.head()
# Out:
#                       customer_id_x                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 2  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 3  4c06b42fbf7b97ab10779cda5549cd1c  07d190f123147d9e89d4b922543d7948
# 4  8276de07ef25225d412b8462d73f8664  332cf4e83e16004ba7dca932ce82475b
#
#    customer_zip_code_prefix   customer_city  customer_state  \
# 0                     14409        Adilabad  Andhra Pradesh
# 1                      1151    Akkarampalle  Andhra Pradesh
# 2                      8775     Akkayapalle  Andhra Pradesh
# 3                     65075  Chilakaluripet  Andhra Pradesh
# 4                     90010           Eluru  Andhra Pradesh
#
#                            order_id order_status_x order_purchase_timestamp_x  \
# 0  00e7ee1b050b8499577073aeb2a297a1      delivered        2017-05-16 15:05:00
# 1  b2059ed67ce144a36e2aa97d2c9e9ad2      delivered        2018-05-19 16:07:00
# 2  951670f92359f4fe4a63112aa7306eba      delivered        2018-03-13 16:06:00
# 3  997fd4b37386d10b57d4ac8cdec011a6      delivered        2018-07-08 09:59:00
# 4  b63fff1ef8b6201df68bb611ee41129e      delivered        2017-04-02 22:15:00
#
#   order_approved_at_x order_delivered_carrier_date_x  ...  \
# 0     5/16/2017 15:22                5/23/2017 10:47  ...
# 1     5/20/2018 16:19                6/11/2018 14:31  ...
# 2     3/13/2018 17:29                3/27/2018 23:22  ...
# 3      7/8/2018 10:30                7/25/2018 15:12  ...
# 4       4/4/2017 5:55                4/13/2017 16:28  ...
#
#   product_description_lenght product_photos_qty product_weight_g  \
# 0                       1141                  1             8683
# 1                        955                  1             8267
# 2                       1066                  1            12160
# 3                       1128                  1            16133
# 4                        154                  1             2600
#
#    product_length_cm product_height_cm  product_width_cm  Month  \
# 0                 54                64                31    May
# 1                 52                52                17    May
# 2                 56                51                28    Mar
# 3                 63                59                25    Jul
# 4                 40                45                39    Apr
#
#    seller_zip_code_prefix seller_city    seller_state
# 0                    8577  Vijayawada  Andhra Pradesh
# 1                    8577  Vijayawada  Andhra Pradesh
# 2                    8577  Vijayawada  Andhra Pradesh
# 3                    8577  Vijayawada  Andhra Pradesh
# 4                    8577  Vijayawada  Andhra Pradesh
#
# [5 rows x 43 columns]

# %%
Popular_byseller=COOIPPS.groupby(['seller_id','product_category_name']).agg({'order_id':'count'}).rename(columns={'order_id':'Quantity'}).sort_values(by=['Quantity'],ascending=False)
Popular_byseller
# Out:
#                                                             Quantity
# seller_id                        product_category_name
# 1f50f920176fa81dab994f9023523100 Garden_Tools                   1954
# 6560211a19b47992c3666cc44a7e94c0 Watches_Gifts                  1693
# 4a3ca9315b744ce9f8e9374361493884 Bed_Bath_Table                 1686
# da8622b14eb17ae2831f4ac5b9dab84a Bed_Bath_Table                 1362
# 1025f0e2d44d7041d6cf58b6550e0bfa Furniture_Decor                1324
# ...                                                              ...
# 85cc55e048b6bcc90c75afe7f0e72f72 Construction_Tools_Lights         1
#                                  Signaling_And_Security            1
# 85d9eb9ddc5d00ca9336a2219c97bb13 Luggage_Accessories               1
#                                  Market_Place                      1
# ffff564a4f9085cd26170f4732393726 Market_Place                      1
#
# [6352 rows x 1 columns]

# %% [markdown]
# ### g. Popular categories by state, month

# %%
#Popular Categories by Month

Popcateg_bymon=COOIPPS.groupby(['product_category_name','Month']).agg({'product_id':'count'}).rename(columns={'product_id':'Quantity'})
Popcateg_bymon=Popcateg_bymon.sort_values(by=['Month'],ascending=[True])
Popcateg_bymon
# Out:
#                                              Quantity
# product_category_name                 Month
# Agro_Industry_And_Commerce            Apr          12
# Home_Appliances_2                     Apr          26
# Stationery                            Apr         200
# Party_Supplies                        Apr           2
# Consoles_Games                        Apr          66
# ...                                               ...
# Cool_Stuff                            Sep         212
# Small_Appliances_Home_Oven_And_Coffee Sep           1
# Bed_Bath_Table                        Sep         567
# Construction_Tools_Safety             Sep           5
# Watches_Gifts                         Sep         280
#
# [797 rows x 1 columns]

# %%
Popcateg_bystate=COOIPPS.groupby(['product_category_name','customer_state']).agg({'order_id':'count'}).rename(columns={'order_id':'Quantity'})
Popcateg_bystate=Popcateg_bystate.sort_values(by=['Quantity'],ascending=False).drop_duplicates()
Popcateg_bystate
# Out:
#                                           Quantity
# product_category_name  customer_state
# Bed_Bath_Table         Andhra Pradesh         7629
# Health_Beauty          Andhra Pradesh         6202
# Sports_Leisure         Andhra Pradesh         5525
# Furniture_Decor        Andhra Pradesh         5517
# Computers_Accessories  Andhra Pradesh         5020
# ...                                            ...
# Fixed_Telephony        Tamil Nadu                5
# Food_Drink             Madhya Pradesh            4
# Fixed_Telephony        Arunachal Pradesh         3
# Books_Imported         Kerala                    2
# Tablets_Printing_Image Tamil Nadu                1
#
# [230 rows x 1 columns]

# %% [markdown]
# ### h. List top 10 most expensive products sorted by price

# %%
COOIPPS.loc[:,['product_category_name','price']].sort_values(by='price',ascending=False).head(15)
# Out:
#        product_category_name    price
# 112762            Housewares   6735.0
# 114718             Computers   6729.0
# 102397                   Art   6499.0
# 112286      Small_Appliances   4799.0
# 112284      Small_Appliances   4690.0
# 106321             Computers   4590.0
# 66046    Musical_Instruments  4399.87
# 88532         Consoles_Games  4099.99
# 104550        Sports_Leisure   4059.0
# 26922          Watches_Gifts   3999.9
# 112301      Small_Appliances   3999.0
# 112302      Small_Appliances   3999.0
# 116491                  <NA>   3980.0
# 100991          Garden_Tools   3930.0
# 52813                   Baby   3899.0

# %% [markdown]
# ## 2. Performing Customers/sellers Segmentation
# ### a. Divide the customers into groups based on the revenue generated

# %%
Customer_Segment=COOIPPS.groupby('customer_unique_id')[['Total_Payment']].sum()
Customer_Segment=Customer_Segment.rename(columns={'Total_Payment':'Amount_Spend'})
Customer_Segment['Customer Group']=np.where(Customer_Segment.Amount_Spend<1000,'Low Revnue Customer',np.where(Customer_Segment.Amount_Spend>3000,'High Revenue Customer','Mid Revenue Customer'))
Customer_Segment
# Out:
#                                   Amount_Spend         Customer Group
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2        1135.2   Mid Revenue Customer
# 0000b849f77a49e4a4ce2b2a4ca5be3f         27.19    Low Revnue Customer
# 0000f46a3911fa3c0805444483337064        689.76    Low Revnue Customer
# 0000f6ccb0745a6a4b88665a16c9f078        174.48    Low Revnue Customer
# 0004aac84e0df4da2b147fca70cf8255       1181.34   Mid Revenue Customer
# ...                                        ...                    ...
# fffcf5a5ff07b0908bd4e2dbc735a684       41348.4  High Revenue Customer
# fffea47cd6d3cc0a88bd621562a9d061         84.58    Low Revnue Customer
# ffff371b4d645b6ecea244b27531430a        112.46    Low Revnue Customer
# ffff5962728ec6157033ef9805bacc48        668.45    Low Revnue Customer
# ffffd2657e2aad2907e67c3e9daecbeb        286.24    Low Revnue Customer
#
# [95419 rows x 2 columns]

# %% [markdown]
# ### b. Divide the sellers into groups based on the revenue generated

# %%
Seller_Segment=COOIPPS.groupby('seller_id')[['price']].sum()
Seller_Segment=Seller_Segment.rename(columns={'price':'Amount_Sold'})
Seller_Segment['Seller Group']=np.where(Seller_Segment.Amount_Sold<1000,'Low Revenue Seller',np.where(Seller_Segment.Amount_Sold>2000,'High Revenue Seller','Mid Revenue Seller'))
Seller_Segment
# Out:
#                                   Amount_Sold         Seller Group
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532       2685.0  High Revenue Seller
# 001cca7ae9ae17fb1caed9dfb1094831     25248.93  High Revenue Seller
# 001e6ad469a905060d959994f1b41e4f        250.0   Low Revenue Seller
# 002100f778ceb8431b7a1020ff7ab48f       1283.2   Mid Revenue Seller
# 003554e2dce176b5555353e4f3555ac8        120.0   Low Revenue Seller
# ...                                       ...                  ...
# ffcfefa19b08742c5d315f2791395ee5         69.9   Low Revenue Seller
# ffdd9f82b9a447f6f8d4b91554cc7dd3       2140.8  High Revenue Seller
# ffeee66ac5d5a62fe688b9d26f83f534      1839.86   Mid Revenue Seller
# fffd5413c0700ac820c7069d66d98c89       9360.9  High Revenue Seller
# ffff564a4f9085cd26170f4732393726       1426.3   Mid Revenue Seller
#
# [3095 rows x 2 columns]

# %% [markdown]
# ## 3. Cross-Selling (Which products are selling together)

# %%
Group=COOIPPS.groupby(['order_id','product_category_name'])[['product_id']].count().sort_values(by='product_id',ascending=False).rename(columns={'product_id':'Count'})
Group.head(10)
# Out:
#                                                              Count
# order_id                         product_category_name
# 895ab968e7bb0d5659d16cd74cd1650c Bed_Bath_Table                 42
# fedcd9f7ccdc8cba3a18defedd1a5547 Office_Furniture               38
# fa65dad1b0e818e3ccc5cb0e39231352 Garden_Tools                   29
# ccf804e764ed5650cd8759557269dc13 Bed_Bath_Table                 26
# 465c2e1bee4561cb39e0db8c5993aafc Agro_Industry_And_Commerce     24
# c6492b842ac190db807c15aff21a7dd6 Garden_Tools                   24
# a3725dfe487d359b5be08cac48b64ec5 Computers_Accessories          24
# 285c2e15bebd4ac83635ccc563dc71f4 Electronics                    22
# 8272b63d03f5f79c56e9e4120aec44ef Health_Beauty                  21
# 895ab968e7bb0d5659d16cd74cd1650c Housewares                     21

# %%
Cross_Sell = COOIPPS[COOIPPS.duplicated(['order_purchase_timestamp_x','customer_id_x'], keep=False)].sort_values(by='order_purchase_timestamp_x')
Cross_Sell = Cross_Sell.loc[:,['customer_id_x','order_purchase_timestamp_x','product_category_name' ]]

Cross_Sell.drop_duplicates(inplace=True)
Cross_Sell = Cross_Sell[Cross_Sell.duplicated(['order_purchase_timestamp_x','customer_id_x'],keep=False)].sort_values(by='order_purchase_timestamp_x').reset_index()

Cross_Sell.drop(columns = 'index',axis=1, inplace=True)

Cross_Sell
# Out:
#                          customer_id_x order_purchase_timestamp_x  \
# 0     3f6f000d5b0a959f38481fad4ab7cac2        2016-10-04 23:59:00
# 1     3f6f000d5b0a959f38481fad4ab7cac2        2016-10-04 23:59:00
# 2     5cdec0bb8cbdf53ffc8fdc212cd247c6        2016-10-09 00:56:00
# 3     5cdec0bb8cbdf53ffc8fdc212cd247c6        2016-10-09 00:56:00
# 4     5263febf1413e9a60ceb7b842008b7ef        2016-10-09 22:36:00
# ...                                ...                        ...
# 1585  72a366446dd3abfc90c598896714d85c        2018-08-26 11:02:00
# 1586  e5a8aaccb766e00177b0a587979cc814        2018-08-26 11:44:00
# 1587  e5a8aaccb766e00177b0a587979cc814        2018-08-26 11:44:00
# 1588  c24bbeb8111fea27eab791a37e665210        2018-08-27 12:39:00
# 1589  c24bbeb8111fea27eab791a37e665210        2018-08-27 12:39:00
#
#                 product_category_name
# 0                      Bed_Bath_Table
# 1                     Furniture_Decor
# 2                       Health_Beauty
# 3                           Perfumery
# 4                      Bed_Bath_Table
# ...                               ...
# 1585                   Bed_Bath_Table
# 1586  Construction_Tools_Construction
# 1587                             Auto
# 1588                     Garden_Tools
# 1589                       Housewares
#
# [1590 rows x 3 columns]

# %% [markdown]
# ## 4. Payment Behaviour
# ### a. How customers are paying?

# %%
COOIPPS.groupby('payment_installments')[['customer_id_x']].count().rename(columns={'customer_id_x':'Customers paying in x no.of Installmnets'})
# Out:
#                       Customers paying in x no.of Installmnets
# payment_installments
# 0                                                            3
# 1                                                        58617
# 2                                                        13722
# 3                                                        11756
# 4                                                         7979
# 5                                                         6017
# 6                                                         4617
# 7                                                         1828
# 8                                                         5063
# 9                                                          726
# 10                                                        6845
# 11                                                          25
# 12                                                         163
# 13                                                          18
# 14                                                          16
# 15                                                          92
# 16                                                           7
# 17                                                           7
# 18                                                          38
# 20                                                          21
# 21                                                           5
# 22                                                           1
# 23                                                           1
# 24                                                          34

# %% [markdown]
# ### b. Which payment channels are used by most customers

# %%
Payment_Type=COOIPPS.groupby('payment_type')[['payment_type']].count().rename(columns={'payment_type':'No. of Transactions'})
Payment_Type
# Out:
#               No. of Transactions
# payment_type
# UPI                         22867
# credit_card                 86769
# debit_card                   1691
# voucher                      6274

# %%
Payment_Type.plot(kind='bar',figsize=(18,7), grid = True)
# Out:
# <AxesSubplot:xlabel='payment_type'>

# %% [markdown]
# ## 5. Customer satisfaction towards category & product
# ### a. Which categories (top 10) are maximum rated & minimum rated?

# %%
COOIPPS_Review=pd.merge(left=COOIPPS,right=Order_Review_Ratings,on='order_id')
COOIPPS_Review.head(10)
# Out:
#                       customer_id_x                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 2  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 3  4c06b42fbf7b97ab10779cda5549cd1c  07d190f123147d9e89d4b922543d7948
# 4  8276de07ef25225d412b8462d73f8664  332cf4e83e16004ba7dca932ce82475b
# 5  8c4a94e823813e9e03460f5f42ce4fe8  be4656d02bf1e9d6663764ac9c7909ef
# 6  d703cdda08125e2b263b92746af0f23c  4669d94e1e35f2493af76862ff85beba
# 7  03f7c28100418ce57927a01d62a6cdf3  ff80f08b2a6a87e84a28bda4613f99bf
# 8  3d14c748bab7ae77e8dff7a9efb1bd38  c1c7632732a487b1221e7bfb627c575f
# 9  3d14c748bab7ae77e8dff7a9efb1bd38  c1c7632732a487b1221e7bfb627c575f
#
#    customer_zip_code_prefix   customer_city  customer_state  \
# 0                     14409        Adilabad  Andhra Pradesh
# 1                      1151    Akkarampalle  Andhra Pradesh
# 2                      8775     Akkayapalle  Andhra Pradesh
# 3                     65075  Chilakaluripet  Andhra Pradesh
# 4                     90010           Eluru  Andhra Pradesh
# 5                     35160      Malkajgiri  Andhra Pradesh
# 6                      1527    Akkarampalle  Andhra Pradesh
# 7                     21010       Badepalle  Andhra Pradesh
# 8                     24220     Jaggayyapet  Andhra Pradesh
# 9                     24220     Jaggayyapet  Andhra Pradesh
#
#                            order_id order_status_x order_purchase_timestamp_x  \
# 0  00e7ee1b050b8499577073aeb2a297a1      delivered        2017-05-16 15:05:00
# 1  b2059ed67ce144a36e2aa97d2c9e9ad2      delivered        2018-05-19 16:07:00
# 2  951670f92359f4fe4a63112aa7306eba      delivered        2018-03-13 16:06:00
# 3  997fd4b37386d10b57d4ac8cdec011a6      delivered        2018-07-08 09:59:00
# 4  b63fff1ef8b6201df68bb611ee41129e      delivered        2017-04-02 22:15:00
# 5  076594c6ae7f8e1157b7321c148efa86      delivered        2017-07-01 09:43:00
# 6  5aadbda0877e0d99ba07f785cd29c362      delivered        2018-06-24 18:02:00
# 7  3f695ee2567af0b169e482d825ec8e31      delivered        2017-11-28 16:15:00
# 8  c43d312cae83cf5e4a99152bf27be2ee      delivered        2017-07-28 20:25:00
# 9  c43d312cae83cf5e4a99152bf27be2ee      delivered        2017-07-28 20:25:00
#
#   order_approved_at_x order_delivered_carrier_date_x  ... product_height_cm  \
# 0     5/16/2017 15:22                5/23/2017 10:47  ...                64
# 1     5/20/2018 16:19                6/11/2018 14:31  ...                52
# 2     3/13/2018 17:29                3/27/2018 23:22  ...                51
# 3      7/8/2018 10:30                7/25/2018 15:12  ...                59
# 4       4/4/2017 5:55                4/13/2017 16:28  ...                45
# 5       7/1/2017 9:55                 7/7/2017 18:44  ...                51
# 6     6/24/2018 18:15                 7/4/2018 15:19  ...                52
# 7     11/30/2017 2:21                12/8/2017 11:42  ...                64
# 8     7/28/2017 20:43                 8/9/2017 20:14  ...                52
# 9     7/28/2017 20:43                 8/9/2017 20:14  ...                52
#
#   product_width_cm Month  seller_zip_code_prefix seller_city    seller_state  \
# 0               31   May                    8577  Vijayawada  Andhra Pradesh
# 1               17   May                    8577  Vijayawada  Andhra Pradesh
# 2               28   Mar                    8577  Vijayawada  Andhra Pradesh
# 3               25   Jul                    8577  Vijayawada  Andhra Pradesh
# 4               39   Apr                    8577  Vijayawada  Andhra Pradesh
# 5               18   Jul                    8577  Vijayawada  Andhra Pradesh
# 6               35   Jun                    8577  Vijayawada  Andhra Pradesh
# 7               35   Nov                    8577  Vijayawada  Andhra Pradesh
# 8               17   Jul                    8577  Vijayawada  Andhra Pradesh
# 9               17   Jul                    8577  Vijayawada  Andhra Pradesh
#
#                           review_id  review_score review_creation_date  \
# 0  88b8b52d46df026a9d1ad2136a59b30b             4       5/26/2017 0:00
# 1  5ad6695d76ee186dc473c42706984d87             5       6/15/2018 0:00
# 2  059a801bb31f6aab2266e672cab87bc5             5       3/29/2018 0:00
# 3  2518803238cabbf63564593e4a8fc52d             1        8/9/2018 0:00
# 4  84467f1766775ba4c14fc25b3ca67905             4        5/3/2017 0:00
# 5  beb271943a2ce45d5726c91897dcef3b             5       7/21/2017 0:00
# 6  5e5291cbe834b53c9b92820ba481708a             4        7/7/2018 0:00
# 7  5e024034244da20b532d9e902a9a1c67             2      12/29/2017 0:00
# 8  2e06a7c08496c0d694303a2331d46dbf             5       8/16/2017 0:00
# 9  2e06a7c08496c0d694303a2331d46dbf             5       8/16/2017 0:00
#
#   review_answer_timestamp
# 0         5/30/2017 22:34
# 1         6/15/2018 12:10
# 2          4/2/2018 18:36
# 3         8/14/2018 11:40
# 4          5/3/2017 21:06
# 5         7/24/2017 13:18
# 6           7/8/2018 2:25
# 7          1/2/2018 17:36
# 8          8/17/2017 8:17
# 9          8/17/2017 8:17
#
# [10 rows x 47 columns]

# %%
Max_Rated_Category=COOIPPS_Review.groupby('product_category_name')[['review_score']].sum().sort_values(by='review_score',ascending=False).head(10)
print("Top 10 Maximum Rated Category :")
Max_Rated_Category
# Out:
# Top 10 Maximum Rated Category :
#                        review_score
# product_category_name
# Bed_Bath_Table                46366
# Health_Beauty                 41315
# Sports_Leisure                36856
# Furniture_Decor               34407
# Computers_Accessories         32002
# Housewares                    29854
# Watches_Gifts                 24856
# Telephony                     18612
# Garden_Tools                  18412
# Auto                          17770

# %%
Max_Rated_Category.plot(kind='bar',figsize=(18,7),y='review_score', grid = True)
# Out:
# <AxesSubplot:xlabel='product_category_name'>

# %%
Min_Rated_Category=COOIPPS_Review.groupby('product_category_name')[['review_score']].sum().sort_values(by='review_score',ascending=True).head(10)
print("Top 10 Minimum Rated Category :")
Min_Rated_Category
# Out:
# Top 10 Minimum Rated Category :
#                                    review_score
# product_category_name
# Security_And_Services                         5
# Fashion_Childrens_Clothes                    36
# La_Cuisine                                   63
# Cds_Dvds_Musicals                            65
# Arts_And_Craftmanship                        99
# Home_Comfort_2                              105
# Diapers_And_Hygiene                         127
# Fashion_Sport                               132
# Flowers                                     139
# Furniture_Mattress_And_Upholstery           156

# %%
Min_Rated_Category.plot(kind='bar',figsize=(18,7),y='review_score',grid=True)
# Out:
# <AxesSubplot:xlabel='product_category_name'>

# %% [markdown]
# ### b. Which products (top10) are maximum rated & minimum rated?

# %%
# TOP 10 Maximum Rated Products
COOIPPS_Review.loc[:,['product_category_name','review_score']].sort_values(by='review_score',ascending=False).head(10)
# Out:
#       product_category_name  review_score
# 37252            Housewares             5
# 48260         Watches_Gifts             5
# 89173            Housewares             5
# 89175            Housewares             5
# 48264         Watches_Gifts             5
# 48263         Watches_Gifts             5
# 48262         Watches_Gifts             5
# 48261         Watches_Gifts             5
# 48257         Watches_Gifts             5
# 48285         Watches_Gifts             5

# %%
# TOP 10 Minimum Rated Products
COOIPPS_Review.loc[:,['product_category_name','review_score']].sort_values(by='review_score',ascending=True).head(10)
# Out:
#        product_category_name  review_score
# 118314           Electronics             1
# 80835             Housewares             1
# 22220          Health_Beauty             1
# 22219        Furniture_Decor             1
# 22213      Home_Construction             1
# 22212        Furniture_Decor             1
# 80859          Health_Beauty             1
# 80875          Health_Beauty             1
# 80880          Health_Beauty             1
# 80881             Stationery             1

# %% [markdown]
# ### c. Average rating by location, seller, product category name, month etc

# %%
# Average Rating by location

COOIPPS_Review.groupby('customer_state')[['review_score']].mean()
# Out:
#                    review_score
# customer_state
# Andhra Pradesh         3.995275
# Arunachal Pradesh      4.024242
# Chhattisgarh           4.031524
# Delhi                     4.029
# Goa                         4.8
# Gujarat                 4.03757
# Haryana                4.117066
# Himachal Pradesh       3.988399
# Jammu & Kashmir        3.998362
# Karnataka              4.015122
# Kerala                 4.051685
# Madhya Pradesh         3.996443
# Maharashtra            4.093023
# Orissa                 4.087393
# Punjab                 4.166882
# Rajasthan              4.098592
# Tamil Nadu             4.112464
# Uttar Pradesh          4.132203
# Uttaranchal            3.718182
# West Bengal            4.002342

# %%
COOIPPS_Review.groupby('customer_state').review_score.mean().round(2).plot(kind = 'pie')
# Out:
# <AxesSubplot:ylabel='review_score'>

# %%
# Average Rating by seller

COOIPPS_Review.groupby('seller_id')[['review_score']].mean()
# Out:
#                                   review_score
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532      3.666667
# 001cca7ae9ae17fb1caed9dfb1094831      3.883817
# 001e6ad469a905060d959994f1b41e4f           1.0
# 002100f778ceb8431b7a1020ff7ab48f      4.033898
# 003554e2dce176b5555353e4f3555ac8           5.0
# ...                                        ...
# ffcfefa19b08742c5d315f2791395ee5           1.0
# ffdd9f82b9a447f6f8d4b91554cc7dd3      4.285714
# ffeee66ac5d5a62fe688b9d26f83f534      4.214286
# fffd5413c0700ac820c7069d66d98c89       3.83871
# ffff564a4f9085cd26170f4732393726           2.1
#
# [3095 rows x 1 columns]

# %%
# Average Rating by Product Category Name

COOIPPS_Review.groupby('product_category_name')[['review_score']].mean()
# Out:
#                             review_score
# product_category_name
# Agro_Industry_And_Commerce      4.150794
# Air_Conditioning                 3.92053
# Art                             3.917808
# Arts_And_Craftmanship              4.125
# Audio                           3.824147
# ...                                  ...
# Stationery                      4.176381
# Tablets_Printing_Image          4.045977
# Telephony                       3.938214
# Toys                             4.14249
# Watches_Gifts                   4.000644
#
# [71 rows x 1 columns]

# %%
# Average Rating by Month

COOIPPS_Review.groupby('Month')[['review_score']].mean()
# Out:
#        review_score
# Month
# Apr        4.036545
# Aug        4.204288
# Dec        3.927987
# Feb        3.788968
# Jan        3.943279
# Jul         4.16924
# Jun        4.156802
# Mar        3.781311
# May        4.118807
# Nov        3.825638
# Oct        4.011661
# Sep        4.123128

# %%
COOIPPS_Review.groupby('Month').review_score.mean().round(2).plot(kind='bar',figsize=(18,7),grid=True)
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ## Assignment 6 Marketing Analytics for E-Commerce Market Place Company
